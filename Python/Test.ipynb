# %%
import matplotlib.pyplot as plot

labels = ['Excel', 'Python', 'Estatística', 'CSS']
sizes = [25, 25, 25, 25]
colors = ['#1a4848ff', '#f58900ff', '#f4d47cff', '#082c6cff']

plot.pie(sizes,labels=labels, wedgeprops=dict(width=0.2), startangle=100, colors=colors)
plot.show()

# %% [markdown]
# # Veja só o que eu consigo fazer com esse bloco de notas

# %% [markdown]
# Posso criar gráficos com python

# %%
from matplotlib import pyplot as fig

x = [1, 2, 3]
y = [2, 4, 6]

fig.plot(x, y)
fig.show()
